# %%
import numpy as np
import os
from random import shuffle
import re

# %%
from bokeh.models import ColumnDataSource, LabelSet
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="22c81134-7283-4ab6-843c-d6660c982c26">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# <h1> Preparing the data </h1>

# %%
import urllib.request
import zipfile
import lxml.etree

# %%
# Download the dataset if it's not already there: this may take a minute as it is 75MB
if not os.path.isfile('ted_en-20160408.zip'):
    urllib.request.urlretrieve("https://wit3.fbk.eu/get.php?path=XML_releases/xml/ted_en-20160408.zip&filename=ted_en-20160408.zip", filename="ted_en-20160408.zip")

# %% [markdown]
# We now extract pairs of (text,label) from our TED data

# %%
with zipfile.ZipFile('ted_en-20160408.zip', 'r') as z:
    doc = lxml.etree.parse(z.open('ted_en-20160408.xml', 'r'))
input_keywords = '\n'.join(doc.xpath('//head/keywords/text()'))
input_text = doc.xpath('//content/text()')
input_text[5][0:100]
input_text[296]
# Out:
# '(Music)\n(Applause)'

# %% [markdown]
# Next we format the input keywords correctly, ensuruing that each talk is represented by one symbol of the set {ooo,Too,oEo,ooD,TEo,oED,ToD,TED}.

# %%
labels_ted = []
for labels in input_keywords.split('\n'):
    labels_ted.append(labels.split(', '))
tech_labels = []
edu_labels = []
des_labels = []
for talk_labels in labels_ted:
    if 'technology' in talk_labels:
        tech_labels.append('T')
    else:
        tech_labels.append('o')
    if 'education' in talk_labels:
        edu_labels.append('E')
    else:
        edu_labels.append('o')
    if 'design' in talk_labels:
        des_labels.append('D')
    else:
        des_labels.append('o')
labels = [tech_labels[i]+edu_labels[i]+ des_labels[i] for i in range(len(tech_labels))]
print(labels[1:15])
# Out:
# ['ooo', 'ooo', 'ooD', 'ToD', 'ooo', 'ooo', 'ooo', 'oEo', 'ToD', 'ooo', 'ooD', 'ooo', 'ToD', 'oEo']

# %%
documents = list(zip(input_text,labels))
(documents[5][0][0:50]+'...',documents[5][1])
# Out:
# ('It began with one question: If Africa was a bar, w...', 'ooo')

# %% [markdown]
# <h1> The model </h1>
#
# First we split our data into training and test

# %%
from random import shuffle
print(len(documents))
shuffle(documents)
training = documents[0:1585]
validation = documents[1585:1585+250]
test = documents[1585+250:1585+500]
# Out:
# 2085

# %% [markdown]
# Next we tokenise all the talks into words within sentences

# %%
def tokenise(text):
    sentences = []
    #remove all paraenthis
    re.sub(r'\([^)]*\)', '', text)
    for line in text.split('\n'):
        m = re.match(r'^(?:(?P<precolon>[^:]{,20}):)?(?P<postcolon>.*)$', line)
        sentences.extend(sent for sent in m.groupdict()['postcolon'].split('.') if sent)
    talk = []
    for sentence in sentences:
        tokens = re.sub(r"[^a-z0-9]+", " ", sentence.lower()).split()
        talk.append(tokens)
    return talk

def sentences(text):
    sentences_tokens = []
    for talk in text:
        sentences_tokens.append((tokenise(talk[0]),talk[1]))
    return sentences_tokens
training_sentences_tokens = sentences(training)    
training_sentences_tokens[5][0][0][0:10]
# Out:
# ['what', 'we', 're', 'really', 'here', 'to', 'talk', 'about', 'is', 'the']

# %% [markdown]
# Now we use wordToVec on our training data to get the word encodings we desire

# %%
#This is the eventual size of the vectors representing documents as well
embedding_size = 50
embedding_window = 5
embedding_min_count = 50

from gensim.models import Word2Vec
#here we need to append all the training talk's sentences
model_input = [['UNK' for n in range(embedding_min_count)]]
for talk in training_sentences_tokens:
    model_input.extend(talk[0])
model = Word2Vec(model_input, size=embedding_size, window = embedding_window, min_count = embedding_min_count, workers=4)

# %%
model['UNK']
# Out:
# array([ 0.38619089, -0.86392337,  0.9644472 , -1.54685473,  1.0534147 ,
#         0.96337509,  1.4925518 ,  0.14948334,  2.20685863, -0.87387383,
#        -0.94482547, -0.02657912, -0.22007377,  0.82772511, -2.09366703], dtype=float32)

# %% [markdown]
# <b> We now lose our sentence stucture as we make each talk a vector of word embeddings </b>

# %%
def to_talk_tokens(data):
    return [[[word for sentence in talk[0] for word in sentence],talk[1]] for talk in data]

training_talks = to_talk_tokens(training_sentences_tokens)
training_talks[5][0][0:10]
# Out:
# ['what', 'we', 're', 'really', 'here', 'to', 'talk', 'about', 'is', 'the']

# %% [markdown]
# <h2> Word 2 Vec Embedding </h2>
#
# Next we define the word 2 vec embedding function given a talk

# %%
import numpy as np
def embeddingW2V(text):
    as_matrix = model[text]
    summed = np.dot(np.ones(len(as_matrix)),as_matrix)
    return summed/len(as_matrix)

# %%
def embedW2V(talk):
    return (embeddingW2V(talk[0]),label_dict[talk[1]])

label_dict = dict()
label_dict['ooo'] =  np.asarray([1,0,0,0,0,0,0,0])
label_dict['Too'] =  np.asarray([0,1,0,0,0,0,0,0])
label_dict['oEo'] =  np.asarray([0,0,1,0,0,0,0,0])
label_dict['ooD'] =  np.asarray([0,0,0,1,0,0,0,0])
label_dict['TEo'] =  np.asarray([0,0,0,0,1,0,0,0])
label_dict['oED'] =  np.asarray([0,0,0,0,0,1,0,0])
label_dict['ToD'] =  np.asarray([0,0,0,0,0,0,1,0])
label_dict['TED'] =  np.asarray([0,0,0,0,0,0,0,1])

# %% [markdown]
# <h2> Glove Embeddings </h2>

# %% [markdown]
# <h2> Generating data into batches ready to train </h2>

# %%
def generate_word_matrix(word_embedding):
    word_dict = dict()
    words = list()
    for i, word in enumerate(model.vocab):
        word_dict[word] = i
        words.append(model[word])
    return word_dict, np.asarray(words)
w2v_dict, w2v_matrix = generate_word_matrix(model)

# %%
def embed_words(talk,word_token_dict):
    talk_into_tokens = np.zeros(5403)
    for i in range(min(len(talk),5403)):
        talk_into_tokens[i] = word_token_dict.get(talk[i],word_token_dict['UNK'])
    return talk_into_tokens

# %%
import random 
def training_data_generator(batch_size, word_token_dict):
    talks_into_tokens = [(embed_words(talk[0],word_token_dict),label_dict[talk[1]]) for talk in training_talks]
    while True:
        random.shuffle(talks_into_tokens)
        for i in range(len(talks_into_tokens)//batch_size):
            batch = talks_into_tokens[50*i:50*i+50]
            yield [np.array([np.array(shit[0]) for shit in batch]),np.array([shit[1] for shit in batch])]

# %%
training_talks[1]
# Out:
# [['i',
#   'really',
#   'am',
#   'honored',
#   'to',
#   'be',
#   'here',
#   'and',
#   'as',
#   'chris',
#   'said',
#   'it',
#   's',
#   'been',
#   'over',
#   '20',
#   'years',
#   'since',
#   'i',
#   'started',
#   'working',
#   'in',
#   'africa',
#   'my',
#   'first',
#   'introduction',
#   'was',
#   'at',
#   'the',
#   'abidjan',
#   'airport',
#   'on',
#   'a',
#   'sweaty',
#   'ivory',
#   'coast',
#   'morning',
#   'i',
#   'had',
#   'just',
#   'left',
#   'wall',
#   'street',
#   'cut',
#   'my',
#   'hair',
#   'to',
#   'look',
#   'like',
#   'margaret',
#   'mead',
#   'given',
#   'away',
#   'most',
#   'everything',
#   'that',
#   'i',
#   'owned',
#   'and',
#   'arrived',
#   'with',
#   'all',
#   'the',
#   'essentials',
#   'some',
#   'poetry',
#   'a',
#   'few',
#   'clothes',
#   'and',
#   'of',
#   'course',
#   'a',
#   'guitar',
#   'because',
#   'i',
#   'was',
#   'going',
#   'to',
#   'save',
#   'the',
#   'world',
#   'and',
#   'i',
#   'thought',
#   'i',
#   'would',
#   'just',
#   'start',
#   'with',
#   'the',
#   'african',
#   'continent',
#   'but',
#   'literally',
#   'within',
#   'days',
#   'of',
#   'arriving',
#   'i',
#   'was',
#   'told',
#   'in',
#   'no',
#   'uncertain',
#   'terms',
#   'by',
#   'a',
#   'number',
#   'of',
#   'west',
#   'african',
#   'women',
#   'that',
#   'africans',
#   'didn',
#   't',
#   'want',
#   'saving',
#   'thank',
#   'you',
#   'very',
#   'much',
#   'least',
#   'of',
#   'all',
#   'not',
#   'by',
#   'me',
#   'i',
#   'was',
#   'too',
#   'young',
#   'unmarried',
#   'i',
#   'had',
#   'no',
#   'children',
#   'didn',
#   't',
#   'really',
#   'know',
#   'africa',
#   'and',
#   'besides',
#   'my',
#   'french',
#   'was',
#   'pitiful',
#   'and',
#   'so',
#   'it',
#   'was',
#   'an',
#   'incredibly',
#   'painful',
#   'time',
#   'in',
#   'my',
#   'life',
#   'and',
#   'yet',
#   'it',
#   'really',
#   'started',
#   'to',
#   'give',
#   'me',
#   'the',
#   'humility',
#   'to',
#   'start',
#   'listening',
#   'i',
#   'think',
#   'that',
#   'failure',
#   'can',
#   'be',
#   'an',
#   'incredibly',
#   'motivating',
#   'force',
#   'as',
#   'well',
#   'so',
#   'i',
#   'moved',
#   'to',
#   'kenya',
#   'and',
#   'worked',
#   'in',
#   'uganda',
#   'and',
#   'i',
#   'met',
#   'a',
#   'group',
#   'of',
#   'rwandan',
#   'women',
#   'who',
#   'asked',
#   'me',
#   'in',
#   '1986',
#   'to',
#   'move',
#   'to',
#   'kigali',
#   'to',
#   'help',
#   'them',
#   'start',
#   'the',
#   'first',
#   'microfinance',
#   'institution',
#   'there',
#   'and',
#   'i',
#   'did',
#   'and',
#   'we',
#   'ended',
#   'up',
#   'naming',
#   'it',
#   'duterimbere',
#   'meaning',
#   'to',
#   'go',
#   'forward',
#   'with',
#   'enthusiasm',
#   'and',
#   'while',
#   'we',
#   'were',
#   'doing',
#   'it',
#   'i',
#   'realized',
#   'that',
#   'there',
#   'weren',
#   't',
#   'a',
#   'lot',
#   'of',
#   'businesses',
#   'that',
#   'were',
#   'viable',
#   'and',
#   'started',
#   'by',
#   'women',
#   'and',
#   'so',
#   'maybe',
#   'i',
#   'should',
#   'try',
#   'to',
#   'run',
#   'a',
#   'business',
#   'too',
#   'and',
#   'so',
#   'i',
#   'started',
#   'looking',
#   'around',
#   'and',
#   'i',
#   'heard',
#   'about',
#   'a',
#   'bakery',
#   'that',
#   'was',
#   'run',
#   'by',
#   '20',
#   'prostitutes',
#   'and',
#   'being',
#   'a',
#   'little',
#   'intrigued',
#   'i',
#   'went',
#   'to',
#   'go',
#   'meet',
#   'this',
#   'group',
#   'and',
#   'what',
#   'i',
#   'found',
#   'was',
#   '20',
#   'unwed',
#   'mothers',
#   'who',
#   'were',
#   'trying',
#   'to',
#   'survive',
#   'and',
#   'it',
#   'was',
#   'really',
#   'the',
#   'beginning',
#   'of',
#   'my',
#   'understanding',
#   'the',
#   'power',
#   'of',
#   'language',
#   'and',
#   'how',
#   'what',
#   'we',
#   'call',
#   'people',
#   'so',
#   'often',
#   'distances',
#   'us',
#   'from',
#   'them',
#   'and',
#   'makes',
#   'them',
#   'little',
#   'i',
#   'also',
#   'found',
#   'out',
#   'that',
#   'the',
#   'bakery',
#   'was',
#   'nothing',
#   'like',
#   'a',
#   'business',
#   'that',
#   'in',
#   'fact',
#   'it',
#   'was',
#   'a',
#   'classic',
#   'charity',
#   'run',
#   'by',
#   'a',
#   'well',
#   'intentioned',
#   'person',
#   'who',
#   'essentially',
#   'spent',
#   '600',
#   'dollars',
#   'a',
#   'month',
#   'to',
#   'keep',
#   'these',
#   '20',
#   'women',
#   'busy',
#   'making',
#   'little',
#   'crafts',
#   'and',
#   'baked',
#   'goods',
#   'and',
#   'living',
#   'on',
#   '50',
#   'cents',
#   'a',
#   'day',
#   'still',
#   'in',
#   'poverty',
#   'so',
#   'i',
#   'made',
#   'a',
#   'deal',
#   'with',
#   'the',
#   'women',
#   'i',
#   'said',
#   'look',
#   'we',
#   'get',
#   'rid',
#   'of',
#   'the',
#   'charity',
#   'side',
#   'and',
#   'we',
#   'run',
#   'this',
#   'as',
#   'a',
#   'business',
#   'and',
#   'i',
#   'll',
#   'help',
#   'you',
#   'they',
#   'nervously',
#   'agreed',
#   'i',
#   'nervously',
#   'started',
#   'and',
#   'of',
#   'course',
#   'things',
#   'are',
#   'always',
#   'harder',
#   'than',
#   'you',
#   'think',
#   'they',
#   're',
#   'going',
#   'to',
#   'be',
#   'first',
#   'of',
#   'all',
#   'i',
#   'thought',
#   'well',
#   'we',
#   'need',
#   'a',
#   'sales',
#   'team',
#   'and',
#   'we',
#   'clearly',
#   'aren',
#   't',
#   'the',
#   'a',
#   'team',
#   'here',
#   'so',
#   'let',
#   's',
#   'i',
#   'did',
#   'all',
#   'this',
#   'training',
#   'and',
#   'the',
#   'epitome',
#   'was',
#   'when',
#   'i',
#   'literally',
#   'marched',
#   'into',
#   'the',
#   'streets',
#   'of',
#   'nyamirambo',
#   'which',
#   'is',
#   'the',
#   'popular',
#   'quarter',
#   'of',
#   'kigali',
#   'with',
#   'a',
#   'bucket',
#   'and',
#   'i',
#   'sold',
#   'all',
#   'these',
#   'little',
#   'doughnuts',
#   'to',
#   'people',
#   'and',
#   'i',
#   'came',
#   'back',
#   'and',
#   'i',
#   'was',
#   'like',
#   'you',
#   'see',
#   'and',
#   'the',
#   'women',
#   'said',
#   'you',
#   'know',
#   'jacqueline',
#   'who',
#   'in',
#   'nyamirambo',
#   'is',
#   'not',
#   'going',
#   'to',
#   'buy',
#   'doughnuts',
#   'out',
#   'of',
#   'an',
#   'orange',
#   'bucket',
#   'from',
#   'a',
#   'tall',
#   'american',
#   'woman',
#   'and',
#   'like',
#   'laughter',
#   'it',
#   's',
#   'a',
#   'good',
#   'point',
#   'so',
#   'then',
#   'i',
#   'went',
#   'the',
#   'whole',
#   'american',
#   'way',
#   'with',
#   'competitions',
#   'team',
#   'and',
#   'individual',
#   'completely',
#   'failed',
#   'but',
#   'over',
#   'time',
#   'the',
#   'women',
#   'learnt',
#   'to',
#   'sell',
#   'on',
#   'their',
#   'own',
#   'way',
#   'and',
#   'they',
#   'started',
#   'listening',
#   'to',
#   'the',
#   'marketplace',
#   'and',
#   'they',
#   'came',
#   'back',
#   'with',
#   'ideas',
#   'for',
#   'cassava',
#   'chips',
#   'and',
#   'banana',
#   'chips',
#   'and',
#   'sorghum',
#   'bread',
#   'and',
#   'before',
#   'you',
#   'knew',
#   'it',
#   'we',
#   'had',
#   'cornered',
#   'the',
#   'kigali',
#   'market',
#   'and',
#   'the',
#   'women',
#   'were',
#   'earning',
#   'three',
#   'to',
#   'four',
#   'times',
#   'the',
#   'national',
#   'average',
#   'and',
#   'with',
#   'that',
#   'confidence',
#   'surge',
#   'i',
#   'thought',
#   'well',
#   'it',
#   's',
#   'time',
#   'to',
#   'create',
#   'a',
#   'real',
#   'bakery',
#   'so',
#   'let',
#   's',
#   'paint',
#   'it',
#   'and',
#   'the',
#   'women',
#   'said',
#   'that',
#   's',
#   'a',
#   'really',
#   'great',
#   'idea',
#   'and',
#   'i',
#   'said',
#   'well',
#   'what',
#   'color',
#   'do',
#   'you',
#   'want',
#   'to',
#   'paint',
#   'it',
#   'and',
#   'they',
#   'said',
#   'well',
#   'you',
#   'choose',
#   'and',
#   'i',
#   'said',
#   'no',
#   'no',
#   'i',
#   'm',
#   'learning',
#   'to',
#   'listen',
#   'you',
#   'choose',
#   'it',
#   's',
#   'your',
#   'bakery',
#   'your',
#   'street',
#   'your',
#   'country',
#   'not',
#   'mine',
#   'but',
#   'they',
#   'wouldn',
#   't',
#   'give',
#   'me',
#   'an',
#   'answer',
#   'so',
#   'one',
#   'week',
#   'two',
#   'weeks',
#   'three',
#   'weeks',
#   'went',
#   'by',
#   'and',
#   'finally',
#   'i',
#   'said',
#   'well',
#   'how',
#   'about',
#   'blue',
#   'and',
#   'they',
#   'said',
#   'blue',
#   'blue',
#   'we',
#   'love',
#   'blue',
#   'let',
#   's',
#   'do',
#   'it',
#   'blue',
#   'so',
#   'i',
#   'went',
#   'to',
#   'the',
#   'store',
#   'i',
#   'brought',
#   'gaudence',
#   'the',
#   'recalcitrant',
#   'one',
#   'of',
#   'all',
#   'and',
#   'we',
#   'brought',
#   'all',
#   'this',
#   'paint',
#   'and',
#   'fabric',
#   'to',
#   'make',
#   'curtains',
#   'and',
#   'on',
#   'painting',
#   'day',
#   'we',
#   'all',
#   'gathered',
#   'in',
#   'nyamirambo',
#   'and',
#   'the',
#   'idea',
#   'was',
#   'we',
#   'would',
#   'paint',
#   'it',
#   'white',
#   'with',
#   'blue',
#   'as',
#   'trim',
#   'like',
#   'a',
#   'little',
#   'french',
#   'bakery',
#   'but',
#   'that',
#   'was',
#   'clearly',
#   'not',
#   'as',
#   'satisfying',
#   'as',
#   'painting',
#   'a',
#   'wall',
#   'of',
#   'blue',
#   'like',
#   'a',
#   'morning',
#   'sky',
#   'so',
#   'blue',
#   'blue',
#   'everything',
#   'became',
#   'blue',
#   'the',
#   'walls',
#   'were',
#   'blue',
#   'the',
#   'windows',
#   'were',
#   'blue',
#   'the',
#   'sidewalk',
#   'out',
#   'front',
#   'was',
#   'painted',
#   'blue',
#   'and',
#   'aretha',
#   'franklin',
#   'was',
#   'shouting',
#   'r',
#   'e',
#   's',
#   'p',
#   'e',
#   'c',
#   't',
#   'the',
#   'women',
#   's',
#   'hips',
#   'were',
#   'swaying',
#   'and',
#   'little',
#   'kids',
#   'were',
#   'trying',
#   'to',
#   'grab',
#   'the',
#   'paintbrushes',
#   'but',
#   'it',
#   'was',
#   'their',
#   'day',
#   'and',
#   'at',
#   'the',
#   'end',
#   'of',
#   'it',
#   'we',
#   'stood',
#   'across',
#   'the',
#   'street',
#   'and',
#   'we',
#   'looked',
#   'at',
#   'what',
#   'we',
#   'had',
#   'done',
#   'and',
#   'i',
#   'said',
#   'it',
#   'is',
#   'so',
#   'beautiful',
#   'and',
#   'the',
#   'women',
#   'said',
#   'it',
#   'really',
#   'is',
#   'and',
#   'i',
#   'said',
#   'and',
#   'i',
#   'think',
#   'the',
#   'color',
#   'is',
#   'perfect',
#   'and',
#   'they',
#   'all',
#   'nodded',
#   'their',
#   'head',
#   'except',
#   'for',
#   'gaudence',
#   'and',
#   'i',
#   'said',
#   'what',
#   'and',
#   'she',
#   'said',
#   'nothing',
#   'and',
#   'i',
#   'said',
#   'what',
#   'and',
#   'she',
#   'said',
#   'well',
#   'it',
#   'is',
#   'pretty',
#   'but',
#   'you',
#   'know',
#   'our',
#   'color',
#   'really',
#   'it',
#   'is',
#   'green',
#   'and',
#   'laughter',
#   'i',
#   'learned',
#   'then',
#   'that',
#   'listening',
#   'isn',
#   't',
#   'just',
#   'about',
#   'patience',
#   'but',
#   'that',
#   'when',
#   'you',
#   've',
#   'lived',
#   'on',
#   'charity',
#   'and',
#   'dependent',
#   'your',
#   'whole',
#   'life',
#   'long',
#   'it',
#   's',
#   'really',
#   'hard',
#   'to',
#   'say',
#   'what',
#   'you',
#   'mean',
#   'and',
#   'mostly',
#   'because',
#   'people',
#   'never',
#   'really',
#   'ask',
#   'you',
#   'and',
#   'when',
#   'they',
#   'do',
#   'you',
#   'don',
#   't',
#   'really',
#   'think',
#   'they',
#   'want',
#   'to',
#   'know',
#   'the',
#   'truth',
#   'and',
#   'so',
#   'then',
#   'i',
#   'learned',
#   'that',
#   'listening',
#   ...],
#  'ooo']

# %%
training_data = training_data_generator(50,w2v_dict)
(next(training_data)[0])
# Out:
# array([[   55.,  2836.,  3741., ...,     0.,     0.,     0.],
#        [ 3310.,  3741.,   943., ...,     0.,     0.,     0.],
#        [ 2394.,  1839.,  1215., ...,     0.,     0.,     0.],
#        ...,
#        [ 1042.,   578.,  4152., ...,     0.,     0.,     0.],
#        [ 1257.,  3108.,  3036., ...,     0.,     0.,     0.],
#        [ 2979.,  1626.,  3243., ...,     0.,     0.,     0.]])

# %%
validation_sentences_tokens = sentences(validation)
validation_as_words = to_talk_tokens(validation_sentences_tokens)
validation_as_tokens = [(embed_words(talk[0],w2v_dict),label_dict[talk[1]]) for talk in validation_as_words]
validation_data = [np.array([np.array(shit[0]) for shit in validation_as_tokens]),np.array([shit[1] for shit in validation_as_tokens])]

# %%
training_data = training_data_generator(50,w2v_dict)
len((next(training_data)[1]))
# Out:
# 50

# %%
import tensorflow as tf

#xavier = tf.contrib.layers.xavier_init
batch_size = 50
hidden_size = 60
learning_rate = 1e-3

def forward_prop(T,E,W,b,V,c):
    X = tf.reduce_mean(tf.nn.embedding_lookup(E,T), axis=1, keep_dims=False)
    print(X)
    h = tf.nn.dropout(tf.nn.relu(tf.matmul(X,W) + b),0.95)
    u = tf.matmul(h,V) + c
    return u

E = tf.Variable(tf.constant(0.0, shape=[len(w2v_matrix), embedding_size]), trainable=True)

embedding_placehold = tf.placeholder(tf.float32, [len(w2v_matrix), embedding_size])
embedding_init = E.assign(embedding_placehold)

T = tf.placeholder(tf.int32, shape= [None,None]) #Batch-size, talk-length
y = tf.placeholder(tf.float32, shape=[None,8]) #Batch-size

W = tf.Variable(tf.random_normal([embedding_size,hidden_size], stddev=0.1))
b = tf.Variable(tf.random_normal([hidden_size], stddev=0.1))

V = tf.Variable(tf.random_normal([hidden_size,8], stddev=0.1))
c = tf.Variable(tf.random_normal([8], stddev=0.1))

u = forward_prop(T,E,W,b,V,c)

prediction = tf.argmax(u, dimension=1)

cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(u, y))
train_step = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(cost)

sess = tf.Session()
sess.run(tf.global_variables_initializer())

correct_prediction = tf.equal(tf.argmax(y,1), tf.argmax(u,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

validaton_acc = []
test_acc = []

for i in range(75):
    avg = 0
    costtt = 0
    for j in range(1585//batch_size):
        batch = next(training_data)
        _, acc, costt = sess.run([train_step,accuracy, cost], feed_dict={T: batch[0], y: batch[1], embedding_placehold: w2v_matrix})
        avg += acc/(1585//batch_size)
        costtt += costt/(1585//batch_size)
    test_acc.append(avg)
    validaton_acc.append(sess.run(accuracy, feed_dict={T: validation_data[0], y: validation_data[1]}))
    if not i % 10: 
        print("epoch" + str(i) + " reee: " + str(acc) + " cost: " + str(costt) + " valid: " +str(validaton_acc[-1]))
        
import matplotlib.pyplot as plt
plt.plot(test_acc)
plt.plot(validaton_acc)
plt.show()
# Out:
# Tensor("Mean_57:0", shape=(?, 15), dtype=float32)
# epoch0 reee: 0.66 cost: 1.3252 valid: 0.528
# epoch10 reee: 0.56 cost: 1.40054 valid: 0.528
# epoch20 reee: 0.48 cost: 1.4346 valid: 0.528
# epoch30 reee: 0.48 cost: 1.3779 valid: 0.528
# epoch40 reee: 0.62 cost: 1.06632 valid: 0.528
# epoch50 reee: 0.6 cost: 1.09855 valid: 0.524
# epoch60 reee: 0.64 cost: 1.01696 valid: 0.544
# epoch70 reee: 0.68 cost: 1.02645 valid: 0.564
